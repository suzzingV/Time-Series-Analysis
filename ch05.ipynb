# %% [markdown]
# <a href="https://colab.research.google.com/github/suzzingV/Time-Series-Analysis/blob/main/ch05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Figure 5.1 : 정상 AR(1) 과정 phi = -0.7
install.packages("astsa")
library(astsa)
set.seed(139672)
z <- 17 + arima.sim(n=102, list(ar=-0.7), rand.gen = rnorm)
ts.plot(z, ylab = "z", main = "그림 5-1 정상 AR(1) 과정 : phi = -0.7"); abline(h=17)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# Plot with title “그림 5-1 정상 AR(1) 과정 : phi = -0.7”

# %%
## Example 5.1
acf(z, maxlag = 24, main = "그림 5-5 AR(1)과정의 ACF : phi = -0.7")
# Out:
# Warning message in plot.window(...):
# “"maxlag" is not a graphical parameter”
# Warning message in plot.xy(xy, type, ...):
# “"maxlag" is not a graphical parameter”
# Warning message in axis(side = side, at = at, labels = labels, ...):
# “"maxlag" is not a graphical parameter”
# Warning message in axis(side = side, at = at, labels = labels, ...):
# “"maxlag" is not a graphical parameter”
# Warning message in box(...):
# “"maxlag" is not a graphical parameter”
# Warning message in title(...):
# “"maxlag" is not a graphical parameter”
# Plot with title “그림 5-5 AR(1)과정의 ACF : phi = -0.7”

# %%
lag.plot(z, 2, do.lines = FALSE)
# Out:
# plot without title

# %%
## Figure 5.2 : 백색잡음과정
set.seed(1236)
a <- rnorm(300, 0, 1)
ts.plot(ts(a), ylab = "random", main = "그림 5-2 백색잡음과정"); abline(h = 0)
# Out:
# Plot with title “그림 5-2 백색잡음과정”

# %%
## Figure 5.3: 절편이 없는 Random Walk
z <- arima.sim(n = 300, list(order = c(0, 1, 0)), rand.gen = rnorm)
ts.plot(z, ylab = "z", main = "그림 5-3 절편이 없는 Random Walk")
# Out:
# Plot with title “그림 5-3 절편이 없는 Random Walk”

# %%
## Figure 5.4: 절편이 있는 Random Walk
set.seed(1246)
z = ts(cumsum(0.2 + rnorm(300, 0, 1))) # cumsum: 주어진 벡터의 누적합 -> 시간에 따라 증가하는 추세를 가진 시계열 데이터를 생성
plot(z, main = "그림 5-4 절편이 있는 Random Walk")
# Out:
# Plot with title “그림 5-4 절편이 있는 Random Walk”

# %%
## Example 5.2 : ;이동평균과정 : theta = 0.8
plot(arima.sim(list(order = c(0, 0, 1), ma = .8), n = 100), ylab = "x", main = (expression(MA(1)~~~theta==.8))); abline(h = 0)
z <- arima.sim(list(order = c(0, 0, 1), ma = .8), n = 100);
pacf(z, maxlag = 24, main = "그림 5-9 MA(1)의 PACF : theta = 0.8")
# Out:
# Warning message in plot.window(...):
# “"maxlag" is not a graphical parameter”
# Warning message in plot.xy(xy, type, ...):
# “"maxlag" is not a graphical parameter”
# Warning message in axis(side = side, at = at, labels = labels, ...):
# “"maxlag" is not a graphical parameter”
# Warning message in axis(side = side, at = at, labels = labels, ...):
# “"maxlag" is not a graphical parameter”
# Warning message in box(...):
# “"maxlag" is not a graphical parameter”
# Warning message in title(...):
# “"maxlag" is not a graphical parameter”
# Plot with title “MA(1) ~ ~~theta == 0.8”
# Plot with title “그림 5-9 MA(1)의 PACF : theta = 0.8”

# %%
#그림 5-10
plot(as.numeric(z - 0.467*lag(z, -1)), as.numeric(lag(z, -2)-0.467*lag(z, -1)), xlab = "z(t)-0.467*z(t+1)", ylab = "z(t+2)-0.467*z(t+1)"); abline(h = 0, v = 0);
# Out:
# plot without title
